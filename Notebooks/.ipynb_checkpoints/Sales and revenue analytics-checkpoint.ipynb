# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
final_df=pd.read_csv("processed/merged_orders_customers.csv")
final_df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8128\1394785118.py:1: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_df=pd.read_csv("processed/merged_orders_customers.csv")
#         Unnamed: 0                          order_id  order_item_id  \
# 0                0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1                1  00018f77f2f0320c557190d7a144bdd3              1
# 2                2  000229ec398224ef6ca0657da4fc703e              1
# 3                3  00024acbcdf0a6daa1e931b038114c75              1
# 4                4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...            ...                               ...            ...
# 112645      112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646      112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647      112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648      112648  fffe18544ffabc95dfada21779c9644f              1
# 112649      112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  total_value  order_month  \
# 0       2017-09-19 09:45:35   58.90          13.29        72.19            9
# 1       2017-05-03 11:05:13  239.90          19.93       259.83            5
# 2       2018-01-18 14:48:30  199.00          17.87       216.87            1
# 3       2018-08-15 10:10:18   12.99          12.79        25.78            8
# 4       2017-02-13 13:57:51  199.90          18.14       218.04            2
# ...                     ...     ...            ...          ...          ...
# 112645  2018-05-02 04:11:01  299.99          43.41       343.40            5
# 112646  2018-07-20 04:31:48  350.00          36.53       386.53            7
# 112647  2017-10-30 17:14:25   99.90          16.95       116.85           10
# 112648  2017-08-21 00:04:32   55.99           8.72        64.71            8
# 112649  2018-06-12 17:10:13   43.00          12.79        55.79            6
#
#         ...  customer_state_x              customer_unique_id_y  \
# 0       ...                RJ  871766c5855e863f6eccc05f988b23cb
# 1       ...                SP  eb28e67c4c0b83846050ddfb8a35d051
# 2       ...                MG  3818d81c6709e39d06b2738a8d3a2474
# 3       ...                SP  af861d436cfc08b2c2ddefd0ba074622
# 4       ...                SP  64b576fb70d441e8f1b2d7d446e483c5
# ...     ...               ...                               ...
# 112645  ...                MA  0c9aeda10a71f369396d0c04dce13a64
# 112646  ...                PR  0da9fe112eae0c74d3ba1fe16de0988b
# 112647  ...                SP  cd79b407828f02fdbba457111c38e4c4
# 112648  ...                SP  eb803377c9315b564bdedad672039306
# 112649  ...                SP  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
#
#         customer_zip_code_prefix_y        customer_city_y  customer_state_y  \
# 0                            28013  campos dos goytacazes                RJ
# 1                            15775        santa fe do sul                SP
# 2                            35661          para de minas                MG
# 3                            12952                atibaia                SP
# 4                            13226        varzea paulista                SP
# ...                            ...                    ...               ...
# 112645                       65077               sao luis                MA
# 112646                       81690               curitiba                PR
# 112647                        4039              sao paulo                SP
# 112648                       13289                vinhedo                SP
# 112649                       18605               botucatu                SP
#
#         total_payment_value  max_installments  zero_payment_flag  \
# 0                     72.19               2.0              False
# 1                    259.83               3.0              False
# 2                    216.87               5.0              False
# 3                     25.78               2.0              False
# 4                    218.04               3.0              False
# ...                     ...               ...                ...
# 112645               343.40               1.0              False
# 112646               386.53               1.0              False
# 112647               116.85               3.0              False
# 112648                64.71               3.0              False
# 112649                55.79               1.0              False
#
#         avg_review_score  has_review_text
# 0                    5.0             True
# 1                    4.0            False
# 2                    5.0             True
# 3                    4.0            False
# 4                    5.0             True
# ...                  ...              ...
# 112645               5.0            False
# 112646               5.0            False
# 112647               5.0            False
# 112648               5.0             True
# 112649               5.0            False
#
# [112650 rows x 46 columns]

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'total_value',
#        'order_month', 'order_year', 'order_day', 'order_weekday',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'delivery_status',
#        'customer_unique_id_x', 'customer_zip_code_prefix_x', 'customer_city_x',
#        'customer_state_x', 'customer_unique_id_y',
#        'customer_zip_code_prefix_y', 'customer_city_y', 'customer_state_y',
#        'total_payment_value', 'max_installments', 'zero_payment_flag',
#        'avg_review_score', 'has_review_text'],
#       dtype='object')

# %%
final_df.shape
# Out:
# (112650, 46)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     112650 non-null  int64
#  1   order_id                       112650 non-null  object
#  2   order_item_id                  112650 non-null  int64
#  3   product_id                     112650 non-null  object
#  4   seller_id                      112650 non-null  object
#  5   shipping_limit_date            112650 non-null  object
#  6   price                          112650 non-null  float64
#  7   freight_value                  112650 non-null  float64
#  8   total_value                    112650 non-null  float64
#  9   order_month                    112650 non-null  int64
#  10  order_year                     112650 non-null  int64
#  11  order_day                      112650 non-null  int64
#  12  order_weekday                  112650 non-null  int64
#  13  product_category_name          112650 non-null  object
#  14  product_name_lenght            112650 non-null  float64
#  15  product_description_lenght     112650 non-null  float64
#  16  product_photos_qty             112650 non-null  float64
#  17  product_weight_g               112650 non-null  float64
#  18  product_length_cm              112650 non-null  float64
#  19  product_height_cm              112650 non-null  float64
#  20  product_width_cm               112650 non-null  float64
#  21  product_category_name_english  112626 non-null  object
#  22  seller_zip_code_prefix         112650 non-null  int64
#  23  seller_city                    112650 non-null  object
#  24  seller_state                   112650 non-null  object
#  25  customer_id                    112650 non-null  object
#  26  order_status                   112650 non-null  object
#  27  order_purchase_timestamp       112650 non-null  object
#  28  order_approved_at              112650 non-null  object
#  29  order_delivered_carrier_date   111456 non-null  object
#  30  order_delivered_customer_date  110196 non-null  object
#  31  order_estimated_delivery_date  112650 non-null  object
#  32  delivery_status                112650 non-null  bool
#  33  customer_unique_id_x           112650 non-null  object
#  34  customer_zip_code_prefix_x     112650 non-null  int64
#  35  customer_city_x                112650 non-null  object
#  36  customer_state_x               112650 non-null  object
#  37  customer_unique_id_y           112650 non-null  object
#  38  customer_zip_code_prefix_y     112650 non-null  int64
#  39  customer_city_y                112650 non-null  object
#  40  customer_state_y               112650 non-null  object
#  41  total_payment_value            112647 non-null  float64
#  42  max_installments               112647 non-null  float64
#  43  zero_payment_flag              112647 non-null  object
#  44  avg_review_score               111708 non-null  float64
#  45  has_review_text                111708 non-null  object
# dtypes: bool(1), float64(13), int64(9), object(23)
# memory usage: 38.8+ MB

# %%
final_df['order_purchase_timestamp'] = pd.to_datetime(final_df['order_purchase_timestamp'])

# %%
final_df['order_date'] = final_df['order_purchase_timestamp'].dt.date
final_df['order_month_year'] = final_df['order_purchase_timestamp'].dt.to_period('M').astype(str)

# %%
(final_df['total_value'] - (final_df['price'] + final_df['freight_value'])).abs().describe()
# Out:
# count    1.126500e+05
# mean     2.109000e-15
# std      9.329871e-15
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.547474e-13
# dtype: float64

# %%
#Defining Revenue Column
final_df['revenue'] = final_df['total_value']

# %%
#Defining total Revenue 
total_revenue = final_df['revenue'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 15843553.24

# %%
#Total orders
total_orders = final_df['order_id'].nunique()
print("Total Orders:", total_orders)
# Out:
# Total Orders: 98666

# %%
#Average order value
AOV=total_revenue/total_orders
print("Average Order value:",AOV)
# Out:
# Average Order value: 160.57763809214927

# %%
#monthly sales trend
monthly_sales = final_df.groupby('order_month_year')['revenue'].sum().reset_index()
monthly_sales.columns = ['month', 'monthly_revenue']
monthly_sales
# Out:
#       month  monthly_revenue
# 0   2016-09           354.75
# 1   2016-10         56808.84
# 2   2016-12            19.62
# 3   2017-01        137188.49
# 4   2017-02        286280.62
# 5   2017-03        432048.59
# 6   2017-04        412422.24
# 7   2017-05        586190.95
# 8   2017-06        502963.04
# 9   2017-07        584971.62
# 10  2017-08        668204.60
# 11  2017-09        720398.91
# 12  2017-10        769312.37
# 13  2017-11       1179143.77
# 14  2017-12        863547.23
# 15  2018-01       1107301.89
# 16  2018-02        986908.96
# 17  2018-03       1155126.82
# 18  2018-04       1159698.04
# 19  2018-05       1149781.82
# 20  2018-06       1022677.11
# 21  2018-07       1058728.03
# 22  2018-08       1003308.47
# 23  2018-09           166.46

# %%
#line chart
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(monthly_sales['month'], monthly_sales['monthly_revenue'], marker='o')
plt.xticks(rotation=45)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %%
#Quarterly Sales Trend
#Created Quarter column
final_df['order_quarter'] = final_df['order_purchase_timestamp'].dt.to_period('Q').astype(str)

# %%
#Quarterly revenue
quarterly_sales = final_df.groupby('order_quarter')['revenue'].sum().reset_index()
quarterly_sales.columns = ['quarter', 'quarterly_revenue']
quarterly_sales
# Out:
#   quarter  quarterly_revenue
# 0  2016Q3             354.75
# 1  2016Q4           56828.46
# 2  2017Q1          855517.70
# 3  2017Q2         1501576.23
# 4  2017Q3         1973575.13
# 5  2017Q4         2812003.37
# 6  2018Q1         3249337.67
# 7  2018Q2         3332156.97
# 8  2018Q3         2062202.96

# %%
#Plot
plt.figure(figsize=(10,5))
plt.plot(quarterly_sales['quarter'], quarterly_sales['quarterly_revenue'], marker='o')
plt.xticks(rotation=45)
plt.title("Quarterly Sales Trend")
plt.xlabel("Quarter")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %%
#Category-wise Revenue
category_revenue = final_df.groupby('product_category_name_english')['revenue'].sum().sort_values(ascending=False).head(15)
category_revenue
# Out:
# product_category_name_english
# bed_bath_table           1449386.81
# health_beauty            1441248.07
# watches_gifts            1305541.61
# sports_leisure           1156656.48
# computers_accessories    1059272.40
# furniture_decor           902511.79
# housewares                778397.77
# cool_stuff                719329.95
# auto                      685384.32
# garden_tools              584219.21
# toys                      561372.55
# baby                      480118.00
# perfumery                 453338.71
# telephony                 394883.32
# office_furniture          342532.65
# Name: revenue, dtype: float64

# %%
#bar chart
plt.figure(figsize=(12,6))
category_revenue.plot(kind='bar')
plt.title("Category-wise Revenue (Top 15)")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.xticks(rotation=75)
plt.show()

# %%
#Product-wise Top 10 Products (by Revenue)
top10_products = final_df.groupby('product_id')['revenue'].sum().sort_values(ascending=False).head(10)
top10_products
# Out:
# product_id
# bb50f2e236e5eea0100680137654686c    67606.10
# d1c427060a0f73f6b889a5c7c61f2ac4    60976.03
# 6cdd53843498f92890544667809f1595    59093.99
# 99a4788cb24856965c36a24e339b6058    51071.60
# d6160fb7873f184099d9bc95e30376af    50326.18
# 3dd2a17168ec895c781a9191c1e95ad7    48212.22
# aca2eb7d00ea1a7b8ebd4e68314663af    44820.76
# 5f504b3a1c75b73d6151be81eb05bdc9    41725.81
# 25c38557cf793876c5abdd5931f922db    40311.95
# 53b36df67ebb7c41585e8d54d6772e08    39957.93
# Name: revenue, dtype: float64

# %%
#bar chart
plt.figure(figsize=(10,5))
top10_products.plot(kind='bar')
plt.title("Top 10 Products by Revenue")
plt.xlabel("Product ID")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
#Peak sales by Month
peak_month = final_df.groupby('order_month')['revenue'].sum().sort_values(ascending=False)
peak_month
# Out:
# order_month
# 8     1915420.28
# 5     1838919.88
# 3     1605768.65
# 6     1565004.24
# 7     1509698.92
# 4     1469833.60
# 2     1241104.31
# 1     1079242.42
# 12    1045836.66
# 11    1027375.70
# 10     817489.03
# 9      727859.55
# Name: revenue, dtype: float64

# %%
#plot
plt.figure(figsize=(8,5))
peak_month.sort_index().plot(kind='bar')
plt.title("Revenue by Month")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
#Peak sales by Weekday
peak_weekday = final_df.groupby('order_weekday')['revenue'].sum()
peak_weekday
# Out:
# order_weekday
# 0    2879232.07
# 1    2793649.77
# 2    2906072.93
# 3    4309746.89
# 4    2470882.00
# 5      71771.22
# 6     412198.36
# Name: revenue, dtype: float64

# %%
#plot
weekday_map = {0:"Mon",1:"Tue",2:"Wed",3:"Thu",4:"Fri",5:"Sat",6:"Sun"}
peak_weekday_named = peak_weekday.rename(index=weekday_map)

plt.figure(figsize=(8,5))
peak_weekday_named.plot(kind='bar')
plt.title("Revenue by Weekday")
plt.xlabel("Weekday")
plt.ylabel("Revenue")
plt.show()

# %%
kpi = {
    "Total Revenue": total_revenue,
    "Total Orders": total_orders,
    "Average Order Value": AOV,
    "Total Customers": final_df['customer_unique_id_x'].nunique()
}

kpi
# Out:
# {'Total Revenue': np.float64(15843553.24),
#  'Total Orders': 98666,
#  'Average Order Value': np.float64(160.57763809214927),
#  'Total Customers': 95420}
